# %% [markdown]
# ### What is String:
# - A string is a sequence of characters.
# - Strings are immutable. This means that they cannot be changed after they are created
# - Computers do not deal with characters, they deal with numbers (binary). Even though you may see characters on    your screen, internally it is stored and manipulated as a combination of 0's and 1's.
# - This conversion of character to a number is called encoding, and the reverse process is decoding. ASCII and Unicode are some of the popular encoding used.
#
# ### Strings are Arrays
# Like many other popular programming languages, strings in Python are arrays of bytes representing unicode characters. However, Python does not have a character data type, a single character is simply a string with a length of 1. Square brackets can be used to access elements of the string.

# %% [markdown]
# ### Creating String

# %% [markdown]
# Primarily, there are  three types of creating  strings in Python :
#
# * Single Quote String – (‘Single Quote String’)
# * Double Quote String – (“Double Quote String”)
# * Triple Quote String – (‘’’ Triple Quote String ‘’’)

# %%
str1 = 'Single Quote String'
str2 = "Double Quote String"
str3 = '''Triple Quote String '''

print(str1)
print(str2)
print(str3)
# Out:
# Single Quote String
# Double Quote String
# Triple Quote String

# %% [markdown]
# ### String Slicing - Accessing characters in String

# %% [markdown]
# #### String Slicing
# * The String slicing method is used to access a range of characters in the String.
# * slicing is piece of the value of a string,It denoted by `[ ] `
# * Slicing in a String is done by using a slicing operator, i.e., a colon (:).
# <br>
# * The syntax for slicing is `var[start:stop:step]`
#     - start: the beginning index of the group of elements we want to access
#     - stop: the ending index of the group of elements we want to access
#     - step: how many elements to skip, when accessing a group of elements
#
#
# #### String Indexing
# * The String Indexing method is used to access a individual characters in the String.
# 1. Positive Indexing - The 0th element will be the first character of the string. Use positive indexing to access characters from left to right.
# 2. Negative Indexing - The -1 element will be the last character of the string.Use negative indexing to access characters from right to left.
# <br>
#     - The index must be an integer. We can't use float or other types, this will result into TypeError.
#     - Trying to access a character out of index range will raise an IndexError.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
str_1 = "Python World"
print(str_1)
# Out:
# Python World

# %%
# Positive indexing
str_1[1] # return second charater in the word
# Out:
# 'y'

# %%
#Negative indexing
str_1[-1] # return last charater in the world
# Out:
# 'd'

# %%
# Printing 3rd to 8th character
print(str_1[3:8])
# Out:
# hon W

# %%
# Get the characters from the start to position 5 (not included):
print(str_1[:5])
# Out:
# Pytho

# %%
# Get the characters from position 2, and all the way to the end:
print(str_1[2:])
# Out:
# thon World

# %%
print(str_1[-9:-4])
# Out:
# hon W

# %% [markdown]
# ### Skip character

# %% [markdown]
# * In string slicing, we sometimes need to give a skip value i.e. string[n:m:skip_value].
# * This simply takes every skip_valueth character.
# * By default, the skip value is 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(str_1)
print(str_1[0:8:2])
# Out:
# Python World
# Pto

# %%
print(str_1[-8:-2:2])
# Out:
# o o

# %% [markdown]
# ### String reverse

# %% [markdown]
# the slice statement [::-1] means start at the end of the string and end at position 0, move with the step -1, negative one, which means one step backwards

# %%
print(str_1[::-1])
# Out:
# dlroW nohtyP

# %%
print(str_1[::-2])
# Out:
# drWnhy

# %% [markdown]
# ### Looping Through a String

# %%
for x in "banana":
  print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %% [markdown]
# ### Check String

# %% [markdown]
# * To check if a certain phrase or character is present in a string, we can use the keyword 'in'.
# * To check if a certain phrase or character is not present in a string, we can use the keyword 'not'

# %%
txt = "The best things in life are free!"
print("free" in txt)
# Out:
# True

# %%
txt = "The best things in life are free!"
print("expensive" not in txt)
# Out:
# True

# %% [markdown]
# ### String Modification

# %% [markdown]
# Python provides an wide range of built-in methods that make string manipulation simple and efficient

# %% [markdown]
# #### 1. upper(): Converts all characters in the string to uppercase.

# %%
a = "Hello, World!"
print(a.upper())
print(a)
# Out:
# HELLO, WORLD!
# Hello, World!

# %% [markdown]
# #### 2. lower(): Converts all characters in the string to lowercase.

# %%
print(a.lower())
print(a)
# Out:
# hello, world!
# Hello, World!

# %%
b = a.lower()
print(a,b)
# Out:
# Hello, World! hello, world!

# %% [markdown]
# #### 3. capitalize(): Capitalizes the first character of the string and makes the rest lowercase.

# %%
print(a)
print(a.capitalize())
# Out:
# Hello, World!
# Hello, world!

# %% [markdown]
# #### 4. title(): Capitalizes the first letter of each word in the string.

# %%
print(a)
print(a.title())
# Out:
# Hello, World!
# Hello, World!

# %% [markdown]
# #### 5. swapcase(): Swap the cases of all characters in a string

# %%
print(a)
print(a.swapcase())
# Out:
# Hello, World!
# hELLO, wORLD!

# %% [markdown]
# #### 6. strip(): removes any whitespace from the beginning or the end:

# %%
abc = " Welcome to Python World "
print(abc.strip())
# Out:
# Welcome to Python World

# %% [markdown]
# #### 7. replace(): replaces a string with another string:

# %%
print(abc)
print(abc.replace("Welcome to", "Hello"))
# Out:
#  Welcome to Python World
#  Hello Python World

# %% [markdown]
# #### 8. split(): returns a list where the text between the specified separator becomes the list items.

# %%
txt = abc.split()
print(txt)
# Out:
# ['Welcome', 'to', 'Python', 'World']

# %% [markdown]
# #### 9.casefold() : Converts string into lower case

# %%
print(abc.casefold())
# Out:
#  welcome to python world

# %% [markdown]
# #### 10.center() : Returns a centered string

# %%
print(abc.center(50))
# Out:
#              Welcome to Python World

# %%
print(abc.center(50,'*'))
# Out:
# ************ Welcome to Python World *************

# %% [markdown]
# #### 11. count() : Returns the number of times a specified value occurs in a string

# %%
abc.count('W')
# Out:
# 2

# %% [markdown]
# #### 12. encode() :- Returns an encoded version of the string

# %%
abc.encode()
# Out:
# b' Welcome to Python World '

# %% [markdown]
# #### 13.endswith() :-Returns true if the string ends with the specified value

# %%
abc.endswith(".")
# Out:
# False

# %% [markdown]
# #### 14.startswith() :- Returns true if the string starts with the specified value

# %%
abc.startswith(" ")
# Out:
# True

# %%
abc.startswith("W")
# Out:
# False

# %% [markdown]
# #### 15. expandtabs():-Sets the tab size of the string

# %%
xyz = "H\te\nl\tl\no"
x =  xyz.expandtabs(2)
print(x)
# Out:
# H e
# l l
# o

# %% [markdown]
# #### 16. find():- Searches the string for a specified value and returns the position of where it was found

# %%
abc.find("Welcome")
# Out:
# 1

# %% [markdown]
# #### 17. index() :-Searches the string for a specified value and returns the position of where it was found

# %%
abc.index("Welcome")
# Out:
# 1

# %%
abc[0]
# Out:
# ' '

# %%
abc[1]
# Out:
# 'W'

# %% [markdown]
# ###  String Check

# %% [markdown]
# 1. isalnum():-	Returns True if all characters in the string are alphanumeric
# 2. isalpha():-	Returns True if all characters in the string are in the alphabet
# 3. isascii():-	Returns True if all characters in the string are ascii characters
# 4. isdecimal():-	Returns True if all characters in the string are decimals
# 5. isdigit():-	Returns True if all characters in the string are digits
# 6. isidentifier():-	Returns True if the string is an identifier
# 7. islower():-	Returns True if all characters in the string are lower case
# 8. isnumeric():-	Returns True if all characters in the string are numeric
# 9. isprintable():-	Returns True if all characters in the string are printable
# 10. isspace():-	Returns True if all characters in the string are whitespaces
# 11. istitle():-	Returns True if the string follows the rules of a title
# 12. isupper():-	Returns True if all characters in the string are upper case

# %%
print("isalnum ",abc.isalnum())
print("isalpha ",abc.isalpha())	
print("isascii ",abc.isascii())	
print("isdecimal ",abc.isdecimal())	
print("isdigit ",abc.isdigit())	
print("isidentifier ",abc.isidentifier())	
print("islower ",abc.islower())
print("isnumeric ",abc.isnumeric())	
print("isprintable ",abc.isprintable())	
print("isspace ",abc.isspace())
print("istitle ",abc.istitle())	
print("isupper " ,abc.isupper())
# Out:
# isalnum  False
# isalpha  False
# isascii  True
# isdecimal  False
# isdigit  False
# isidentifier  False
# islower  False
# isnumeric  False
# isprintable  True
# isspace  False
# istitle  False
# isupper  False

# %% [markdown]
# #### 18.join():-	Converts the elements of an iterable into a string

# %%
print(txt)
print(" ".join(txt))
# Out:
# ['Welcome', 'to', 'Python', 'World']
# Welcome to Python World

# %% [markdown]
# #### 19.ljust():- Returns a left justified version of the string

# %%
txt = "banana"
x = txt.ljust(20)
print(x, "is my favorite fruit.")
# Out:
# banana               is my favorite fruit.

# %% [markdown]
# #### 20. rjust():-	Returns a right justified version of the string

# %%
txt = "banana"
x = txt.rjust(20)
print(x, "is my favorite fruit.")
# Out:
#               banana is my favorite fruit.

# %% [markdown]
# #### 21.lstrip():-	Returns a left trim version of the string

# %%
print(x.lstrip())
# Out:
# banana

# %% [markdown]
# #### 22.rstrip():-	Returns a right trim version of the string

# %%
print(x.rstrip())
# Out:
#               banana

# %% [markdown]
# #### 22.maketrans():-	Returns a translation table to be used in translations

# %% [markdown]
# * The maketrans() method returns a mapping table that can be used with the translate() method to replace specified characters.
# * syntax :- str.maketrans(x, y, z)
# * Parameter	Description
#     * x = Required. If only one parameter is specified, this has to be a dictionary describing how to perform the replace. If two or more parameters are specified, this parameter has to be a string specifying the characters you want to replace.
#     * y = Optional. A string with the same length as parameter x. Each character in the first parameter will be replaced with the corresponding character in this string.
#     * z = Optional. A string describing which characters to remove from the original string.

# %%
txt = "Hello Sam!"
mytable = str.maketrans("S", "P")
print(txt.translate(mytable))
# Out:
# Hello Pam!

# %%
txt = "Hi Sam!"
x = "mSa"
y = "eJo"
mytable = str.maketrans(x, y)
print(txt.translate(mytable))
# Out:
# Hi Joe!

# %% [markdown]
# #### 23.partition():-	Returns a tuple where the string is parted into three parts

# %% [markdown]
# * The partition() method searches for a specified string, and splits the string into a tuple containing three elements.
# * The first element contains the part before the specified string.
# * The second element contains the specified string.
# * The third element contains the part after the string.
# * If the specified value is not found, the partition() method returns a tuple containing: 1 - the whole string, 2 - an empty string, 3 - an empty string:
# * Syntax :- string.partition(value)
# * Notes :- Searches for first occurances of the word

# %%
txt = "I could eat bananas all day"

x = txt.partition("apples")
y = txt.partition("bananas")
print(x)
print(y)
# Out:
# ('I could eat bananas all day', '', '')
# ('I could eat ', 'bananas', ' all day')

# %% [markdown]
# #### 24.rfind():-	Searches the string for a specified value and returns the last position of where it was found

# %%
print(abc)
print(abc.rfind("W"))
# Out:
#  Welcome to Python World
# 19

# %% [markdown]
# #### 25.rindex():-	Searches the string for a specified value and returns the last position of where it was found

# %%
print(abc.rindex("W"))
# Out:
# 19

# %% [markdown]
# #### 26.rpartition():-	Returns a tuple where the string is parted into three parts

# %% [markdown]
# * The rpartition() method searches for the last occurrence of a specified string, and splits the string into a tuple containing three elements.
# * The first element contains the part before the specified string.
# * The second element contains the specified string.
# * The third element contains the part after the string.
# * If the specified value is not found, the rpartition() method returns a tuple containing: 1 - an empty string, 2 - an empty string, 3 - the whole string.
# * Syntax :- string.rpartition(value)
# * Notes :- It Searches for last occurances of the world

# %%
txt = "I could eat bananas all day, bananas are my favorite fruit"
x = txt.rpartition("apples")
y = txt.rpartition("bananas")
print(x)
print(y)
# Out:
# ('', '', 'I could eat bananas all day, bananas are my favorite fruit')
# ('I could eat bananas all day, ', 'bananas', ' are my favorite fruit')

# %% [markdown]
# #### 27.rsplit():-	Splits the string at the specified separator, and returns a list

# %%
txt = "apple, banana, cherry"
x = txt.rsplit(", ")
print(x)
# Out:
# ['apple', 'banana', 'cherry']

# %% [markdown]
# #### 28. splitlines():- Splits the string at line breaks and returns a list
# The splitlines() method splits a string into a list. The splitting is done at line breaks

# %%
txt = "Thank you for the music\nWelcome to the jungle"
x = txt.splitlines()
print(x)
# Out:
# ['Thank you for the music', 'Welcome to the jungle']

# %% [markdown]
# #### 29. zfill():-	Fills the string with a specified number of 0 values at the beginning
# * The zfill() method adds zeros (0) at the beginning of the string, until it reaches the specified length.
# * If the value of the len parameter is less than the length of the string, no filling is done.

# %%
txt = "Welcome"

x = txt.zfill(10)

print(x)
# Out:
# 000Welcome

# %% [markdown]
# #### 30. String format
# * The format() method formats the specified value(s) and insert them inside the string's placeholder.
# * The placeholder is defined using curly brackets: {}. Read more about the placeholders in the Placeholder section below.
# * The format() method returns the formatted string.

# %%
txt1 = "My name is {fname}, I'm {age}".format(fname = "John", age = 36)
txt2 = "My name is {0}, I'm {1}".format("John",36)
txt3 = "My name is {}, I'm {}".format("John",36)
print(txt1)
print(txt2)
print(txt3)
# Out:
# My name is John, I'm 36
# My name is John, I'm 36
# My name is John, I'm 36

# %% [markdown]
# ### String Concatenation
# To concatenate, or combine, two strings you can use the + operator.

# %%
a = "Hello"
b = "World"
c = a + " " + b
print(c)
# Out:
# Hello World

# %%
age = 36
txt = "My name is John, I am " + age
print(txt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 2
#       1 age = 36
# ----> 2 txt = "My name is John, I am " + age
#       3 print(txt)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ### F-Strings
# * we can combine strings and numbers by using f-strings or the format() method!
# * To specify a string as an f-string, simply put an f in front of the string literal, and add curly brackets {} as placeholders for variables and other operations.
# * A placeholder can contain variables, operations, functions, and modifiers to format the value.

# %%
txt = f"The price is {20 * 59} dollars"
print(txt)
# Out:
# The price is 1180 dollars

# %%
price = 59
txt = f"The price is {price:.2f} dollars"
print(txt)
# Out:
# The price is 59.00 dollars

# %%
print(f"Hello Welcome to the {'Python World'}")
# Out:
# Hello Welcome to the Python World

# %%
print("We are the so-called \"Vikings\" from the north.")
# Out:
# We are the so-called "Vikings" from the north.

# %% [markdown]
# ### Escape Character
# * To insert characters that are illegal in a string, use an escape character.
# * An escape character is a backslash \ followed by the character you want to insert.

# %% [markdown]
# 1. \\'	Single Quote
# 2. \\\	Backslash
# 3. \n	New Line
# 4. \r	Carriage Return
# 5. \t	Tab
# 6. \b	Backspace
# 7. \f	Form Feed
# 8. \ooo	Octal value
# 9. \xhh	Hex value

# %%
# Single Quote
print('It\'s alright.')
# Out:
# It's alright.

# %%
# Backslash 
print("This will insert one \\ (backslash).")
# Out:
# This will insert one \ (backslash).

# %%
txt = "Hello\nWorld!"
print(txt)
# Out:
# Hello
# World!

# %%
txt = "Hello\rWorld!"
print(txt)
# Out:
# World!

# %%
txt = "Hello\tWorld!"
print(txt)
# Out:
# Hello	World!

# %%
#This example erases one character (backspace):
txt = "Hello \bWorld!"
print(txt)
# Out:
# HelloWorld!

# %%
#A backslash followed by three integers will result in a octal value:
txt = "\110\145\154\154\157"
print(txt)
# Out:
# Hello

# %%
#A backslash followed by an 'x' and a hex number represents a hex value:
txt = "\x48\x65\x6c\x6c\x6f"
print(txt)
# Out:
# Hello
