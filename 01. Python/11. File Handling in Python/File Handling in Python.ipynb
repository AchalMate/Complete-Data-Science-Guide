# %% [markdown]
# * File handling in Python involves working with files such as creating, reading, writing, and closing them.
# * It’s a fundamental part of many applications where data needs to be stored or accessed persistently.
# * Python provides built-in functions to handle files easily

# %% [markdown]
# ### Types of Files in Python:
# * Text files: Files that contain plain text (e.g., .txt, .csv).
# * Binary files: Files that contain binary data (e.g., images, executables).

# %% [markdown]
# ### Operations:
# ### 1. Opening a File:
# * To work with a file, you first need to open it using the open() function.
# * The open() function takes two parameters:
#     * File Name: The name (and path) of the file.
#     * Mode: Specifies the purpose of opening the file. Common modes include:
#         * 'r': Read (default mode).
#         * 'w': Write (creates a new file if it doesn't exist, or truncates the file if it exists).
#         * 'a': Append (adds data to the end of the file without truncating).
#         * 'b': Binary mode (used in combination with other modes to work with binary files).

# %%
file = open('file1.txt', 'r')
print(file)
# Out:
# <_io.TextIOWrapper name='file1.txt' mode='r' encoding='cp1252'>

# %% [markdown]
# ### 2. Reading a File:
#
# * read(): Reads the entire content of the file.
# * readline(): Reads one line at a time.
# * readlines(): Reads all lines as a list of strings.

# %%
content = file.read()  # Reads the entire file
content
# Out:
# 'Hello Everyone!\nWelcome to Python \nThis is File Handling notes'

# %%
print(content)
file.close()
# Out:
# Hello Everyone!
# Welcome to Python
# This is File Handling notes

# %%
file = open('file1.txt', 'r')
content1 = file.readline()  
print(content1)
file.close()
# Out:
# Hello Everyone!

# %%
file = open('file1.txt', 'r')
content2 = file.readlines()  
print(content2)
file.close()
# Out:
# ['Hello Everyone!\n', 'Welcome to Python \n', 'This is File Handling notes']

# %%
file = open('file1.txt', 'r')
content3 = file.readlines()  
for line in content3:
    print(line)
# Out:
# Hello Everyone!
#
# Welcome to Python
#
# This is File Handling notes

# %%
file = open('file1.txt', 'r')
file.readline()
for line in file:
    print(line)
# Out:
# Welcome to Python
#
# This is File Handling notes

# %%
file = open('file1.txt', 'r')
file.readline(10)
# Out:
# 'Hello Ever'

# %% [markdown]
# ### 3. Writing to a File:
#
# * write(): Writes a string to the file.
# * writelines(): Writes a list of strings to the file (without adding line breaks).

# %%
file = open('newfile.txt','w')
print(file)
# Out:
# <_io.TextIOWrapper name='newfile.txt' mode='w' encoding='cp1252'>

# %%
file.write("Hello Python")
file.close()

# %%
file = open('newfile.txt','w')
file.write("Python is important for Interview")
file.close()

# %%
file = open('newfile.txt')
file.read()
# Out:
# 'Python is important for Interview'

# %%
file.close()

# %%
f = open('newfile.txt','a')
f.write("So pratice it daily")
# Out:
# 19

# %%
f.close()

# %%
f = open('newfile.txt','a')
f.writelines(["Solve pratice problems\n", "Complete the assesment \n"]) 
f.close()

# %% [markdown]
# ### File Pointer:
# * When reading or writing to a file, Python maintains a file pointer, which indicates the current position in the file.
# * You can manipulate the file pointer using:
#
# 1. tell(): Returns the current position of the file pointer.
# 2. seek(offset, from_what): Moves the file pointer to a new position.
# from_what: Can be 0 (beginning of the file), 1 (current position), or 2 (end of the file).

# %%
file = open('file1.txt', 'r')
file.seek(3)
# Out:
# 3

# %%
file.read()
# Out:
# 'lo Everyone!\nWelcome to Python \nThis is File Handling notes'

# %%
file.tell() # Prints the current file pointer position
# Out:
# 64

# %%
with open('download.jfif', 'rb') as file:
    data = file.read()
    print(data)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\t\x06\x07\x13\x13\x12\x15\x13\x12\x13\x16\x15\x15\x16\x17\x19\x18\x16\x18\x16\x17\x17\x18\x16\x18\x1a\x1a\x18\x1a\x18\x16\x19\x18\x17\x19\x1d( \x1f\x1b%\x1b\x17\x18#1"%)+...\x1a\x1f583-7(-.+\x01\n\n\n\x0e\r\x0e\x1b\x10\x10\x1b-& &----+----/-0/-------------------------------------\xff\xc0\x00\x11\x08\x01+\x00\xa8\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1c\x00\x00\x01\x05\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05\x01\x02\x03\x04\x06\x00\x07\x08\xff\xc4\x00D\x10\x00\x02\x01\x02\x04\x03\x06\x03\x04\x07\x06\x06\x02\x03\x00\x00\x01\x02\x11\x00\x03\x04\x12!1\x05AQ\x06\x13"aq\x812\x91\xa1BR\xb1\xc1\x14#b\x82\xd1\xe1\xf0\x07\x153Cr\x92\x16$s\xa2\xb2\xf1c\xa3S\xc2\xd2\xff\xc4\x00\x19\x01\x00\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x03\x04\x01\x00\x05\xff\xc4\x008\x11\x00\x01\x03\x02\x03\x06\x05\x03\x03\x03\x03\x05\x00\x00\x00\x00\x01\x00\x02\x11\x03!\x121A\x04Qaq\x81\xf0\x91\xa1\xb1\xc1\xd1\x13"2\x05\xe1\xf1#3r\x14B\x92$Rb\x82\xa2\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\xf3\xea\xe3R\x11S\xf0\xde\x1dr\xfd\xc1n\xd2\xe6c\xaf@\xa3\xab\x1eB\x8c\x98\xb9G\x1b\x95:\xea\xf4\x13\xd9,.\x12\xc9\xbd\x8bf\xbaG\xd9\x04\xaa\x96\xe4\xaa\x01\x04\x93\xe6c\xc8V\x1f\x1b\x88\x17\x1c\xb2\xdbK`\xfc)lh\x07!;\xb1\xf3;\xf9h\x02\xa9\xd5\x15\'\x08\xb6\xfe\xee\x89\xf4\x8b?#}\xca\xa6ZB*VB7\x04z\x8aa\xa6\xa5\xa6E%:\xba\xb5bm%8\x8aJ\xe5\xc9\xb5\xd5g\x11\x86(\x14\xca\xb0a \xab\x03\xea\x08\xdc\x11\xcc\x10*\n\xc0A\xb8ZA\x06\nm4\x8ay\x14w\x8fp\xa4\x16m\xe2\xec\xfc\x0e\x88n\'\xdch\x08\xf9c\xa3n<\xc9\xf2\xacu@\xd2\x01\xd6\xdd\x7f}\x11S\xa4\xe7\x82[\xa0\x9e\x9a\xf8,\xed!\x14\xf1]\x14ij8\xa4"\x9fHk\x97(\xcd6\xa44\xd4x \xe8c\xa8\x04\x1fPw\x15\xcb\x13+\xab]\x80\xe1X\\]\xb2\xc8\r\x9b\x8b\xf1\xaa\x92@<\x88V\x99S\xe5\x15\xd4\x9f\xf5\x0c\x06\x1dc\xb8\xaaF\xcbP\x89l\x11\xbe~`\xa1il\xb1\n\xa2Y\x88\n\x06\xe4\x93\x00|\xeb\xd8\xbb/\xc0W\x0bh \xd5\xce\xb7\x1b\xef7\xff\x00\xc8\xd8\x7f\x12k\x07\xfd\x9f\xe0\x85\xccXb4\xb4\xa5\xbfx\xf8W\xf1\'\xda\xbd7\x8bb\xbb\x9c=\xdb\xa3tF+\xe6\xd1\n?\xdd\x15&\xd6\xf2\\)\x84\xfd\x9d\xb01\x95\x85\xed\x188\xdcWv5\xb5d\x95\x03\x91}\xae1\xf7\xf0\x8fC\xd6\xa8v\x93\x1a\xb85\x16l\xa8\xef[O!\xd4\x98\xfb \x11=I\x03\xadj;;\x82\x16l\xe7:\x95Ru\xdc\x98\xe6|\xcdyo\x16\xc5\x9b\x97\xef]&|E\x14\xf9!\x82}\xdf1\xf7\xa3\xd9\xda\x1f\'F\xd8s\xcezf\xb6\xbb\xfe\x98\x00fs>_\xb2\x81\x8e\xa4\xb3\x16c\xf11\xdc\xff\x00.\x83aL\xcfC\xaf\xe2u\xa5\xb7~\xadP"\x13]P[\xbbS)\xae\\\x96\x92\x9e+Y\x80\xec\x82\x8b#\x11\x8b\xbam\xdb\x80\xd9\x10x\xc81\x94\x12v&F\x80s\xdcr]J\xac\xa6%\xdf\xb9\xe4\x98\xcaN\xa8a\xa1d\x1b\xa7=\x0f\xcc\x02>`\x83\xefIS\xf6\x8f\x1c.b\xd9\x90\x05P\xa8\xa1G\xd9\n!W\xd4,Uu4m2\x01+*3\x03\xcbw%\xa7\xbd\xe6\xc8\xd6\xf3\x10\xad\xa1\x1c\xb7Rc\xa4\xe5\x1f*e!\xad\x89\xcd\x08$d\x98\xabK\x14\xe8\xa6\xd7!HE5\x94\x80\x0f"H\x07\xcdB\x92>L\xbf:\x93-h;]\xc1\x0e\x1f\x03cIe\xb8M\xc29\x17S>\xc3*\x89\xf2\xa5\xd4\xac\xd69\xad\xd5\xc6;\xf2\xf1N\xa7E\xcfk\xdd\xa3D\xf7\xd2OE\x9f\xc3\xb9V\x0c7\x14p\xa0l\xacu\x0f\xb1 n7\r\xfbC\xeb \xf3\xa08S"\x8fp\xb1\x99nZ\xea\xa6\xe2y2\t?4\xcd\xf2^\x94F\xf6(\x99 b\x1e\x1b\xd5\xbc\x17\x0e6\xae-\xdbZ\x11\xa3\x0f\xb2\xcaw\x11\xf8y\x81ID8\x1d\xec\xcb\xaf*\xea\x81\xee\xbc;E\xe8\xb1\x82%\xa6\x01\xdc\xb4}\x9a\xc1\x8bX\xecb\x8d\x8fv\xeb\xfe\x97\xce\xdf\xf9f\x1e\xd4k\xb6\x07\xfeP\x8f\xbdr\xc8\xf6\xefP\x9f\xa0\xa8^\xdeLb\xbc\x7f\x8bd\xa9>v\xdf2\x8f\x95\xd7\xf9U\x8e\xd5,\xe1\xa7\xee\xdc\xb2\x7f\xfbP\x1f\xa1\xa4\x17bx<\xbd\xbe\x10\x01\x00\x81\xdd\xe5C\xc4Ow\x84s\xe4>\x84\x1f\xca\xbc \xdc\x8bj9\xe5\x04\xfa\x9dO\xd4\xd7\xbbv\x90N\t\xe3\xa7\xe4k\xe7\xcb\x97|#\xd0~\x15~\xc4?\xa5\xd4\xfa\x05\x1e\xd6\x7f\xa9\xd1Cy\xe9-=F\xc6\x9fdUJEz\xd3U\xcbMT\xad\n\xb7mL\x13\xc8o\xe5$\x01\xf5"\xb9hV\xd7Z/\xc6;Gz\xed\x8e\xe5@\\\xd7;\xc6i\x930\x06U\x11\xa0\x99\xd7\xd3\xa5\x04CR\xd2\xddM\xae \xb8e\x92k*9\x93\x84\xc4\xa1\xf60\xb1V\x80\xa9"\xba(\xd2\xd3Uj\xd7\x12\xc0\xbd\x85\xb6n\x02\xa6\xe6hR!\x82\x88\xcaXr\x9f\x16\x9f\xb3\xe7G{\x0f\x89\xb1j\xeb\xdc\x ...

# %%
with open('copy.png','wb') as f:
    info = f.write(data)
    print(info)
# Out:
# 12674
